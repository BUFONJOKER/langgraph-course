# %%
a = 2
b = -3
c = -4

# %%
b_str = '+ '+str(b) if b>0 else '- '+str(-1*b)
c_str = '+ '+str(c) if c>0 else '- '+str(-1*c)

# %%
equation = f"{a}x² {b_str}x {c_str}"

# %%
equation
# Out:
# '2x² - 3x - 4'

# %%
from main import workflow

# %%
workflow

# %%
workflow.invoke({
    'a':a,
    'b':b,
    'c':c
})
# Out:
# {'a': 2, 'b': -3, 'c': -4, 'result': 'Two one real repeated root is 0.75'}
