# %%
from main import graph_workflow

# %%
question = "What is AI?"

# %%
result = graph_workflow.invoke({'question':question})

# %%
from main import subgraph_workflow

# %%
result['urdu_answer']
# Out:
# '**مصنوعی ذہانت (اے آئی)** سے مراد مشینوں، خاص طور پر کمپیوٹر سسٹمز کے ذریعے انسانی ذہانت کی نقالی ہے۔\n\nصرف سخت ہدایات پر عمل کرنے کے بجائے، اے آئی سسٹمز ان کاموں کو انجام دینے کے لیے تیار کیے گئے ہیں جو عام طور پر انسانی ذہنی صلاحیتوں کی ضرورت ہوتی ہے، جیسے کہ:\n\n*   **سیکھنا:** معلومات اور اس کے استعمال کے قواعد حاصل کرنا (اکثر مشین لرننگ کے ذریعے)۔\n*   **استدلال:** قواعد کا استعمال کرتے ہوئے تقریبی یا یقینی نتائج تک پہنچنا۔\n*   **خود درستگی:** فیڈ بیک کی بنیاد پر وقت کے ساتھ کارکردگی میں بہتری لانا۔\n*   **ادراک:** زبان کو سمجھنا، تصاویر کو پہچاننا، یا تقریر کو پروسیس کرنا۔\n\n**اے آئی کی عام مثالیں:**\n*   آواز کے معاونین (سیری، الیکسا، گوگل اسسٹنٹ)۔\n*   تجویزاتی خوارزم (نیٹ فلکس، سپوٹیفائی، ایمیزون)۔\n*   خود مختار گاڑیاں (خود چلنے والی کاریں)۔\n*   تخلیقی اوزار (گفتگو بوٹس، تصویر بنانے والے)۔\n\nآج کل استعمال ہونے والی زیادہ تر اے آئی **"محدود اے آئی"** ہے، جس کا مطلب ہے کہ یہ مخصوص کاموں کو انجام دینے میں انتہائی ماہر ہے لیکن اس میں عام انسانی جیسی خود آگاہی یا موافقت پذ
# ...

# %%
subgraph_workflow

# %%
graph_workflow
