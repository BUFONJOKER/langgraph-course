# %%
from sequential_workflows_01.bmi_calculate_worlflow_01 import bmi_workflow_01
# Out:
# {'weight_kg': 12.0, 'height_m': 12.0, 'bmi': 0.08, 'bmi_category': 'Underweight'}
#   +-----------+
#   | __start__ |
#   +-----------+
#         *
#         *
#         *
# +---------------+
# | bmi_calculate |
# +---------------+
#         *
#         *
#         *
#   +-----------+
#   | label_bmi |
#   +-----------+
#         *
#         *
#         *
#    +---------+
#    | __end__ |
#    +---------+

# %%
bmi_calculate_workflow_01.workflow

# %%
from sequential_workflows_01.simple_workflow_01 import bmi_workflow_01
# Out:
# {'weight_kg': 12.0, 'height_m': 2.0, 'bmi': 3.0, 'bmi_category': 'Underweight'}
#   +-----------+
#   | __start__ |
#   +-----------+
#         *
#         *
#         *
# +---------------+
# | bmi_calculate |
# +---------------+
#         *
#         *
#         *
#   +-----------+
#   | label_bmi |
#   +-----------+
#         *
#         *
#         *
#    +---------+
#    | __end__ |
#    +---------+

# %%
bmi_workflow_01.workflow
