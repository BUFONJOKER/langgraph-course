# %%
from main import workflow
# Out:
# {'runs': 100, 'balls': 37, 'fours': 10, 'sixes': 5, 'strike_rate': 270.27027027027026, 'balls_per_boundary': 2.466666666666667, 'boundary_percent': 15.0, 'summary': '\n    Summary of Batsmen Innings\n    Strike Rate = 270.27\n    Balls per Boundary = 2.47\n    Boundaries Percent = 15.0\n    '}

# %%
workflow

# %%
input_state = {
    'runs': 100,
    'balls': 37,
    'fours': 10,
    'sixes': 5
}

output = workflow.invoke(input=input_state)

# %%
output
# Out:
# {'runs': 100,
#  'balls': 37,
#  'fours': 10,
#  'sixes': 5,
#  'strike_rate': 270.27027027027026,
#  'balls_per_boundary': 2.466666666666667,
#  'boundary_percent': 15.0,
#  'summary': '\n    Summary of Batsmen Innings\n    Strike Rate = 270.27\n    Balls per Boundary = 2.47\n    Boundaries Percent = 15.0\n    '}

# %%
output['summary']
# Out:
# '\n    Summary of Batsmen Innings\n    Strike Rate = 270.27\n    Balls per Boundary = 2.47\n    Boundaries Percent = 15.0\n    '
