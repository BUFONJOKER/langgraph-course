# %%
from main import workflow

# %%
workflow

# %%
from main import model, structured_model
from input_essay import essay

# %%
input_state = {
    'essay':essay,
    'model':model,
    'structured_model':structured_model
}

# %%
model

# %%
structured_model

# %%
output = workflow.invoke(input_state)

# %%
output

# %%
output.keys()
