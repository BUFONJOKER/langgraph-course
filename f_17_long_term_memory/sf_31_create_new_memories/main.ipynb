# %%
from main import workflow

# %%
workflow

# %%
from langchain_core.messages import HumanMessage

# %%
config = {'configurable': {'user_id': 'u1'}}

# %%
result = workflow.invoke({
    'messages': [HumanMessage(content="Hi my name is mani?")]
},config=config)

# %%
result
# Out:
# {'messages': [HumanMessage(content='Hi my name is mani?', additional_kwargs={}, response_metadata={}, id='090cd8fd-1f78-44ef-9dad-517e1ff2c4ed'),
#   SystemMessage(content='Memories updated.', additional_kwargs={}, response_metadata={}, id='740319ce-32e9-46c2-9fe1-31da0fbcf0d6')]}

# %%
from main import store

# %%
items = store.search(('user','u1','details'))

# %%
for item in items:
    print(item.value['data'])
# Out:
# The user's name is Mani.

# %%
result = workflow.invoke({
    'messages': [HumanMessage(content="I am learning genertive ai?")]
},config=config)

# %%
items = store.search(('user','u1','details'))
for item in items:
    print(item.value['data'])
# Out:
# The user's name is Mani.
# The user is learning generative AI.

# %%
result = workflow.invoke({
    'messages': [HumanMessage(content="I am learning genertive ai?")]
},config=config)

# %%
items = store.search(('user','u1','details'))
for item in items:
    print(item.value['data'])
# Out:
# The user's name is Mani.
# The user is learning generative AI.
# The user is learning generative AI.
