# %%
from main import workflow, store
from langchain_core.messages import HumanMessage

# %%
config = {'configurable': {'user_id': 'u1'}}

result = workflow.invoke({
    'messages': [HumanMessage(content="I am learning genertive ai?")]
},config=config)

items = store.search(('user','u1','details'))

for item in items:
    print(item.value['data'])
# Out:
# The user is learning generative AI.

# %%
result = workflow.invoke({
    'messages': [HumanMessage(content="I am learning genertive ai?")]
},config=config)

items = store.search(('user','u1','details'))

for item in items:
    print(item.value['data'])
# Out:
# The user is learning generative AI.

# %%
result = workflow.invoke({
    'messages': [HumanMessage(content="my name is mani?")]
},config=config)

items = store.search(('user','u1','details'))

for item in items:
    print(item.value['data'])
# Out:
# The user is learning generative AI.
# The user's name is Mani.

# %%
result = workflow.invoke({
    'messages': [HumanMessage(content="I am learning genertive ai?")]
},config=config)

items = store.search(('user','u1','details'))

for item in items:
    print(item.value['data'])
# Out:
# The user is learning generative AI.
# The user's name is Mani.
