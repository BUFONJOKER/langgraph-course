# %%
from main import workflow, store
from langchain_core.messages import HumanMessage

# %%
workflow

# %%
config = {
    'configurable': {
        'user_id': 'u1'
    }
}
result = workflow.invoke({
        'messages': [HumanMessage(content="I am learning genertive ai?")]
    },config=config)

print(result['messages'][-1].content)
# Out:
# That's fantastic! Generative AI is such an exciting and rapidly evolving field to dive into. Since I know you're currently focused on learning Generative AI, I can help tailor our conversations to match your learning goals and pace.
#
# Whether you're interested in understanding the underlying architectures (like Transformers or Diffusion models), working with specific frameworks (like PyTorch or Hugging Face), or building practical applications (like RAG pipelines or fine-tuning models), I'm here to support you.
#
# To help me guide you better and personalize the resources I share, here are three questions:
#
# 1. What specific area of Generative AI are you most interested in (e.g., LLMs, Image Generation, Audio, or Code)?
# 2. Are you focusing more on the theoretical math and concepts, or do you prefer hands-on coding and implementation?
# 3. Do you have a specific project or tool in mind that you'd like to build while you're learning?

# %%
items = store.search(('user','u1','details'))

for item in items:
    print(item.value['data'])
# Out:
# User is learning generative AI
