# %%
from main import workflow

# %%
workflow

# %%
config = {'configurable':{'thread_id':'chat_1'}}

initial_state = {
    'messages' : [
        ('user', 'Write a blog on ai')
    ]
}

# %%
workflow.invoke(input={'messages':[('user','what is ai')]}, config=config)
workflow.invoke(input={'messages':[('user','what is ds')]}, config=config)
workflow.invoke(input={'messages':[('user','what is cs')]}, config=config)
workflow.invoke(input={'messages':[('user','what is dl')]}, config=config)
workflow.invoke(input={'messages':[('user','what is ml')]}, config=config)
workflow.invoke(input={'messages':[('user','what is api')]}, config=config)
workflow.invoke(input={'messages':[('user','what is mcp')]}, config=config)
workflow.invoke(input={'messages':[('user','what is llm')]}, config=config)
workflow.invoke(input={'messages':[('user','what is nlp')]}, config=config)
workflow.invoke(input={'messages':[('user','what is gen ai')]}, config=config)
# Out:
# {'messages': [AIMessage(content='In the context of technology and following your sequence of questions (AI, DS, CS, DL, ML, API, MCP), **LLM** stands for **Large Language Model**.\n\n### 1. The Core Definition\nA **Large Language Model** is a specific type of **Artificial Intelligence** model designed to understand, generate, and manipulate human language.\n*   **Training:** It is trained on massive datasets of text (books, websites, code, articles) using **Deep Learning** techniques.\n*   **Function:** It predicts the next word (or token) in a sequence based on the context provided, allowing it to write essays, code, answer questions, or summarize text.\n*   **Architecture:** Most modern LLMs are built on the **Transformer** architecture, which allows them to pay "attention" to different parts of the input text simultaneously.\n\n### 2. The Hierarchy (Where LLM Fits)\nTo visualize where LLM fits with your previous questions, imagine the specific implementation of the broader concepts:\n*   **AI:** The goal (Intelligence).\n*   **ML:** The method (Learning from data).\n*   **DL:** The technique (Neural Networks).\n*   **NLP (Natural Language Processing):** The field (Understanding language).\n*   **LLM:** The **model** (The specific engine built using DL + NLP).\n\n**All LLMs are Deep Learning models, but not all Deep Learning models are LLMs.** (e.g., An image recognition model is DL, but not an LLM).\n\n### 3. Relationship to CS, DS, API, and MCP\nLLMs are the culmination of the stack you have explored so far:\n\n*   **Computer Science (CS):** Provides the computing power (GPUs/TPUs) and engineering required to train and host massive LLMs.\n*   **Data Science (DS):** Provides the curated text data used to train the model.\n*   **Machine/Deep Learning (ML/DL):** Provides the mathematical algorithms (Backpropagation, Attention) that allow the LLM to learn.\n*   **API:** Most users access LLMs via an **API** (e.g., sending a prompt to OpenAI\'s server and getting a response).\n*   **MCP (Model Context Protocol):** This is the new standard that allows the **LLM** to connect to external tools. The LLM is the "brain," and MCP gives it the "hands" to use software.\n\n**Analogy Extension:**\n*   **CS** builds the factory.\n*   **DS** mines the raw materials.\n*   **ML/DL** designs the engine blueprint.\n*   **LLM** is the **finished V12 Engine** installed in the car.\n*   **API** is the steering wheel to control the engine.\n*   **MCP** is the drivetrain connecting the engine to the wheels.\n\n### 4. How It Works (Simplified)\n1.  **Tokenization:** The text you type is broken into chunks called "tokens" (parts of words).\n2.  **Embedding:** These tokens are converted into numbers (vectors) that the neural network can understand.\n3.  **Inference:** The model processes these numbers through its layers (neurons) to calculate probabilities.\n4.  **Generation:** It picks the most likely next token, adds it to the sequence, and repeats the process until it finishes.\n\n### 5. Common Applications\n*   **Chatbots:** Customer service agents or assistants (like me).\n*   **Coding Assistants:** GitHub Copilot suggesting code completions.\n*   **Content Creation:** Writing marketing copy, emails, or scripts.\n*   **Translation:** Translating text between languages instantly.\n*   **Summarization:** Condensing long documents into bullet points.\n\n### 6. Other Common Meanings\nDepending on the context, LLM can also stand for:\n*   **Master of Laws:** An advanced academic degree in law (common in universities).\n*   **Lower Limit:** Used in various engineering or scientific contexts (e.g., Lower Limit of Detection).\n*   **Liquid Limit:** A measure in geotechnical engineering regarding soil consistency.\n\n### Summary\nGiven your previous questions, **LLM refers to Large Language Model**. It is the current state-of-the-art implementation of **Deep Learning** applied to language. It is the "brain" that developers access via **APIs** and connect t ...
#   HumanMessage(content='what is nlp', additional_kwargs={}, response_metadata={}, id='2ec9fc39-da7b-464b-90ea-b4cbbac0dea4'),
#   AIMessage(content='In the context of technology and following your sequence of questions (CS, AI, DS, ML, DL, API, MCP, LLM), **NLP** stands for **Natural Language Processing**.\n\n### 1. The Core Definition\n**Natural Language Processing (NLP)** is a branch of **Artificial Intelligence** that gives computers the ability to understand, interpret, and generate human language.\n*   **Goal:** To bridge the gap between human communication (which is messy, ambiguous, and contextual) and computer understanding (which is structured and logical).\n*   **Scope:** It includes both **Natural Language Understanding (NLU)** (reading/comprehending) and **Natural Language Generation (NLG)** (writing/speaking).\n\n### 2. The Hierarchy (Where NLP Fits)\nNLP is the **domain** or **field of study**, whereas LLM is the **tool** used within that field.\n*   **AI:** The overarching goal (Intelligence).\n*   **NLP:** A specific **branch** of AI (focused on language), similar to how *Computer Vision* is a branch of AI focused on images.\n*   **ML/DL:** The **methods** used to achieve NLP tasks.\n*   **LLM:** The current **state-of-the-art model** used to perform NLP tasks.\n\n**Analogy Extension:**\n*   **AI** is the goal of building a bilingual person.\n*   **NLP** is the **study of language itself** (grammar, vocabulary, meaning).\n*   **ML/DL** are the **learning techniques** the person uses to study.\n*   **LLM** is the **brain** the person developed after studying.\n*   **API** is the **mouth** used to speak.\n*   **MCP** is the **ears** used to listen to external tools.\n\n### 3. Relationship to the Tech Stack\nNLP is the "subject matter" expert in your growing list of technologies:\n*   **CS:** Builds the infrastructure to run NLP algorithms.\n*   **DS:** Cleans and prepares the text data (corpus) for NLP models.\n*   **ML/DL:** Provides the statistical models (like Transformers) that power modern NLP.\n*   **LLM:** Is the specific *type* of DL model currently dominating NLP.\n*   **API:** Allows applications to send text to an NLP system and get results.\n*   **MCP:** Allows the NLP system (LLM) to interact with external data sources using language.\n\n**The Full Picture:**\n*   **CS** is the foundation.\n*   **DS** prepares the fuel.\n*   **AI** is the vehicle.\n*   **ML** is the engine concept.\n*   **DL** is the turbocharger.\n*   **NLP** is the **Road System** (the domain of language the vehicle drives on).\n*   **LLM** is the **Car** driving on that road.\n*   **API** is the steering wheel.\n*   **MCP** is the universal coupling.\n\n### 4. How It Works (Simplified)\nNLP tasks generally involve several layers of analysis:\n1.  **Morphological:** Breaking words into roots (e.g., "running" -> "run").\n2.  **Syntactic:** Analyzing grammar and sentence structure (Parsing).\n3.  **Semantic:** Understanding the meaning of words and sentences.\n4.  **Pragmatic:** Understanding context and intent (e.g., sarcasm or implied meaning).\n\n*Before LLMs*, NLP relied heavily on rigid rules and statistics. *With LLMs*, NLP relies on deep neural networks to understand context probabilistically.\n\n### 5. Common Applications\n*   **Search Engines:** Understanding query intent (Google Search).\n*   **Spam Filters:** Detecting unwanted emails based on content.\n*   **Sentiment Analysis:** Determining if a review is positive or negative.\n*   **Machine Translation:** Google Translate.\n*   **Voice Assistants:** Siri, Alexa, Google Assistant.\n*   **Chatbots:** Customer service bots (powered by LLMs).\n\n### 6. Other Common Meanings\nDepending on the context, NLP can also stand for:\n*   **Neuro-Linguistic Programming (Psychology):**\n    *   **Definition:** A pseudo-scientific approach to communication, personal development, and psychotherapy created in the 1970s. It focuses on the connection between neurological processes, language, and behavioral patterns.\n    *   **Context:** Common in self-help, coaching, and therapy circles. **This is NOT the tech def ...
#   HumanMessage(content='what is gen ai', additional_kwargs={}, response_metadata={}, id='e88a30d4-ab74-4149-8489-1c3f269739ba'),
#   AIMessage(content='In the context of technology and following your sequence of questions (CS, AI, DS, ML, DL, API, MCP, LLM, NLP), **Gen AI** stands for **Generative AI**.\n\n### 1. The Core Definition\n**Generative AI (Gen AI)** is a subset of **Artificial Intelligence** focused on **creating new content** rather than just analyzing or classifying existing data.\n*   **Goal:** To generate original text, images, audio, code, or video that mimics human creativity.\n*   **Mechanism:** It learns patterns from existing data (training) and then uses those patterns to produce novel outputs (inference).\n*   **Distinction:** Traditional AI is **Discriminative** (e.g., "Is this email spam?"). Gen AI is **Generative** (e.g., "Write an email for me.").\n\n### 2. The Hierarchy (Where Gen AI Fits)\nGen AI is the **capability**, while LLM is the **model** that enables it.\n*   **AI:** The overarching field.\n*   **Gen AI:** A **category** of AI (focused on creation).\n*   **NLP:** The **domain** where text-based Gen AI operates.\n*   **LLM:** The **architecture** (model) most commonly used to power Text Gen AI.\n*   **DL/ML:** The **methods** used to train Gen AI models.\n\n**Analogy Extension:**\n*   **Traditional AI:** A **Librarian**. They organize, find, and categorize existing books (data).\n*   **Gen AI:** An **Author**. They write entirely new books (content) based on what they\'ve read.\n*   **LLM:** The **Brain** of the Author.\n*   **NLP:** The **Language** the Author speaks.\n\n### 3. Relationship to the Tech Stack\nGen AI is the **output function** of the stack you have explored so far. It leverages all previous components to create something new:\n\n*   **CS:** Provides the compute power to generate content quickly.\n*   **DS:** Curates the training data that teaches the model what to create.\n*   **ML/DL:** Provides the algorithms (like Transformers or Diffusion) that enable generation.\n*   **NLP:** The specific field where text-based Gen AI operates.\n*   **LLM:** The specific model architecture used for text generation.\n*   **API:** The interface used to request generation (e.g., "Generate an image").\n*   **MCP:** Allows the Gen AI system to access external tools to enhance its creation (e.g., fetching real-time data to include in a generated report).\n\n**The Stack Evolution:**\n*   **CS** is the foundation.\n*   **DS** prepares the fuel.\n*   **AI** is the vehicle.\n*   **ML** is the engine.\n*   **DL** is the turbocharger.\n*   **NLP** is the road system.\n*   **LLM** is the car.\n*   **API** is the steering wheel.\n*   **MCP** is the coupling.\n*   **Gen AI** is the **Manufacturing Plant** (The ability to produce new cargo/vehicles, not just drive).\n\n### 4. How It Works (Simplified)\n1.  **Learning:** The model studies vast amounts of existing content (e.g., all of Wikipedia).\n2.  **Pattern Recognition:** It learns statistical relationships (e.g., "cloud" often follows "sky").\n3.  **Sampling:** When prompted, it doesn\'t just recall data; it **probabilically samples** from learned patterns to create something new.\n4.  **Output:** It produces unique content that didn\'t exist before the prompt was given.\n\n### 5. Common Applications\n*   **Text Generation:** Writing articles, emails, scripts (LLMs).\n*   **Image Generation:** Creating art from text prompts (Midjourney, DALL-E).\n*   **Code Synthesis:** Writing software functions from descriptions (GitHub Copilot).\n*   **Audio/Voice:** Generating speech or music (ElevenLabs, Suno).\n*   **Drug Discovery:** Generating molecular structures for new medicines.\n\n### 6. Other Common Meanings / Confusions\n*   **AGI (Artificial General Intelligence):**\n    *   **Confusion:** Sometimes people confuse "Gen AI" (Generative) with "AGI" (General).\n    *   **Difference:** **Gen AI** creates content but is narrow (it specializes in generation). **AGI** is a hypothetical future AI that possesses human-level general reasoning across all tasks.\n*   **Generation (Tech Gene ...

# %%
state = workflow.get_state(config)

# %%
len(state.values['messages'])
# Out:
# 5

# %%
state.values['messages'][0]
# Out:
# AIMessage(content='In the context of technology and following your sequence of questions (AI, DS, CS, DL, ML, API, MCP), **LLM** stands for **Large Language Model**.\n\n### 1. The Core Definition\nA **Large Language Model** is a specific type of **Artificial Intelligence** model designed to understand, generate, and manipulate human language.\n*   **Training:** It is trained on massive datasets of text (books, websites, code, articles) using **Deep Learning** techniques.\n*   **Function:** It predicts the next word (or token) in a sequence based on the context provided, allowing it to write essays, code, answer questions, or summarize text.\n*   **Architecture:** Most modern LLMs are built on the **Transformer** architecture, which allows them to pay "attention" to different parts of the input text simultaneously.\n\n### 2. The Hierarchy (Where LLM Fits)\nTo visualize where LLM fits with your previous questions, imagine the specific implementation of the broader concepts:\n*   **AI:** The goal (Intelligence).\n*   **ML:** The method (Learning from data).\n*   **DL:** The technique (Neural Networks).\n*   **NLP (Natural Language Processing):** The field (Understanding language).\n*   **LLM:** The **model** (The specific engine built using DL + NLP).\n\n**All LLMs are Deep Learning models, but not all Deep Learning models are LLMs.** (e.g., An image recognition model is DL, but not an LLM).\n\n### 3. Relationship to CS, DS, API, and MCP\nLLMs are the culmination of the stack you have explored so far:\n\n*   **Computer Science (CS):** Provides the computing power (GPUs/TPUs) and engineering required to train and host massive LLMs.\n*   **Data Science (DS):** Provides the curated text data used to train the model.\n*   **Machine/Deep Learning (ML/DL):** Provides the mathematical algorithms (Backpropagation, Attention) that allow the LLM to learn.\n*   **API:** Most users access LLMs via an **API** (e.g., sending a prompt to OpenAI\'s server and getting a response).\n*   **MCP (Model Context Protocol):** This is the new standard that allows the **LLM** to connect to external tools. The LLM is the "brain," and MCP gives it the "hands" to use software.\n\n**Analogy Extension:**\n*   **CS** builds the factory.\n*   **DS** mines the raw materials.\n*   **ML/DL** designs the engine blueprint.\n*   **LLM** is the **finished V12 Engine** installed in the car.\n*   **API** is the steering wheel to control the engine.\n*   **MCP** is the drivetrain connecting the engine to the wheels.\n\n### 4. How It Works (Simplified)\n1.  **Tokenization:** The text you type is broken into chunks called "tokens" (parts of words).\n2.  **Embedding:** These tokens are converted into numbers (vectors) that the neural network can understand.\n3.  **Inference:** The model processes these numbers through its layers (neurons) to calculate probabilities.\n4.  **Generation:** It picks the most likely next token, adds it to the sequence, and repeats the process until it finishes.\n\n### 5. Common Applications\n*   **Chatbots:** Customer service agents or assistants (like me).\n*   **Coding Assistants:** GitHub Copilot suggesting code completions.\n*   **Content Creation:** Writing marketing copy, emails, or scripts.\n*   **Translation:** Translating text between languages instantly.\n*   **Summarization:** Condensing long documents into bullet points.\n\n### 6. Other Common Meanings\nDepending on the context, LLM can also stand for:\n*   **Master of Laws:** An advanced academic degree in law (common in universities).\n*   **Lower Limit:** Used in various engineering or scientific contexts (e.g., Lower Limit of Detection).\n*   **Liquid Limit:** A measure in geotechnical engineering regarding soil consistency.\n\n### Summary\nGiven your previous questions, **LLM refers to Large Language Model**. It is the current state-of-the-art implementation of **Deep Learning** applied to language. It is the "brain" that developers access via **APIs** and connect to data via **M ...

# %%
workflow
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 workflow
#
# NameError: name 'workflow' is not defined
