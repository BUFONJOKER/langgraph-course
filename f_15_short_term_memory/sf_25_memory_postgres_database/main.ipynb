# %%
from main import graph

# %%
database_url = 'postgresql://mani:mani@localhost:5432/short_term_memory_db'

# %%
from langgraph.checkpoint.postgres import PostgresSaver

# %%
config = {'configurable':{'thread_id': 'thread_1'}}

    workflow = graph.compile(checkpointer=checkpoint)


    state = workflow.get_state(config)
    state_values = state.values
    for m in state_values.get('messages',[]):
        print(type(m).__name__, ':', m.content)

    print()

# %%
config = {'configurable':{'thread_id': 'thread_1'}}

# %%
with PostgresSaver.from_conn_string(database_url) as checkpoint:

    workflow = graph.compile(checkpointer=checkpoint)

    state = workflow.get_state(config)
    state_values = state.values
    for m in state_values.get('messages',[]):
        print(type(m).__name__, ':', m.content)
# Out:
# HumanMessage : my name is mani?
# AIMessage : Hello Mani! It's nice to meet you. How can I help you today?
# HumanMessage : What is my name?
# AIMessage : Your name is Mani.

# %%
config = {'configurable':{'thread_id': 'thread_2'}}

# %%
with PostgresSaver.from_conn_string(database_url) as checkpoint:

    workflow = graph.compile(checkpointer=checkpoint)

    state = workflow.get_state(config)
    state_values = state.values
    for m in state_values.get('messages',[]):
        print(type(m).__name__, ':', m.content)
# Out:
# HumanMessage : my name is rathore?
# AIMessage : Nice to meet you, Rathore! How can I assist you today?
# HumanMessage : What is my name?
# AIMessage : Your name is Rathore.
